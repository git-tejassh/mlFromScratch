# %%
import sys
sys.path.append('C:/Users/tjsss/OneDrive/Desktop/machine learning/mlFromScratch')

# %%
from utils.dataLoader import data_loader
from svm import Classifier
import pandas as pd

# %%
df = pd.read_csv('C:/Users/tjsss/OneDrive/Desktop/machine learning/mlFromScratch/SVM/diabetes_csv.csv')

# %%
x = df.drop('Outcome', axis=1, inplace = False)
y = df['Outcome']

x_train = x.iloc[:800]
y_train = y.iloc[:800]
x_test = x.iloc[800:1000]
y_test = y.iloc[800:1000]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
dl = data_loader(x.to_numpy() , y.to_numpy(), split = 0.75 ,batch_size = 1)

# %%
train_df = dl.train_loader()
test_df = dl.test_loader()

# %%
a =train_df[100]
a[0]
# Out:
# tensor([[  1.0000, 163.0000,  72.0000,   0.0000,   0.0000,  39.0000,   1.2220,
#           33.0000]])

# %%
clf = Classifier(lambda_param = 0.3)
clf.train(train_df, test_df, epochs = 100)
clf.history()
# Out:
# ---------- 1 ----------
# Mean Train Loss in Epoch: 1 is: 0.6632857322692871
# Mean Val Loss in Epoch: 1 is: 0.6402999758720398
# ---------- 2 ----------
# Mean Train Loss in Epoch: 2 is: 0.6597740650177002
# Mean Val Loss in Epoch: 2 is: 0.6378641724586487
# ---------- 3 ----------
# Mean Train Loss in Epoch: 3 is: 0.6580150127410889
# Mean Val Loss in Epoch: 3 is: 0.6366432309150696
# ---------- 4 ----------
# Mean Train Loss in Epoch: 4 is: 0.6571338176727295
# Mean Val Loss in Epoch: 4 is: 0.6360288858413696
# ---------- 5 ----------
# Mean Train Loss in Epoch: 5 is: 0.6566926836967468
# Mean Val Loss in Epoch: 5 is: 0.6357232928276062
# ---------- 6 ----------
# Mean Train Loss in Epoch: 6 is: 0.6564716696739197
# Mean Val Loss in Epoch: 6 is: 0.63556969165802
# ---------- 7 ----------
# Mean Train Loss in Epoch: 7 is: 0.6567832827568054
# Mean Val Loss in Epoch: 7 is: 0.6386358737945557
# ---------- 8 ----------
# Mean Train Loss in Epoch: 8 is: 0.6585720181465149
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy on training data
X_train_prediction = clf.predict(x_train.to_numpy())
training_data_accuracy = accuracy_score(y_train.to_numpy(), X_train_prediction)

# %%
print('Accuracy score on training data = ', training_data_accuracy)
# Out:
# Accuracy score on training data =  0.3489583333333333
